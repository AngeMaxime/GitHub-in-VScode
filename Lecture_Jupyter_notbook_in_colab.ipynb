# %% [markdown]
# <a href="https://colab.research.google.com/github/AngeMaxime/GitHub-in-VScode/blob/main/Lecture_Jupyter_notbook_in_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # first section of Training:09 videos

# %% [markdown]
# # Video 1: intrduction to Google colab

# %% [markdown]
# # **This is my notebook**
#
# ## Why Google colab
# - Like Jupyter Notebook + Bonus Feature
# - Hosted BY gOggle
# - Require Google account
# - No installation required
# - Network speed is very fast
# - Write Python code directly inside browser
# - Notebbok file stored in Google Drive
# - Many of Data science Library installed
# - CPU, GPU, and TPU support
#
# <hhtps://colab.research.google.com> or <https://www.google.com/drive>
#
# ```
# # This is formatted as code
# ```

# %%
print("I am handsome")
# Out:
# I am handsome

# %%
2 + 5
# Out:
# 7

# %% [markdown]
# # Video 2: Getting Data into Google Colab

# %% [markdown]
# - Public link
# - Google drive
# - Github link
# - Local drive file

# %%
# Public link
# !wget https://raw.githubusercontent.com/HackBio-Internship/public_datasets/main/R/nhanes.csv
# Out:
# --2026-05-06 10:09:37--  https://raw.githubusercontent.com/HackBio-Internship/public_datasets/main/R/nhanes.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 731489 (714K) [text/plain]
# Saving to: ‘nhanes.csv’
#
# nhanes.csv          100%[===================>] 714.34K  --.-KB/s    in 0.007s
#
# 2026-05-06 10:09:37 (97.1 MB/s) - ‘nhanes.csv’ saved [731489/731489]

# %%
ls
# Out:
# nhanes.csv  sample_data/

# %%
import pandas as pd

# %%
pd.read_csv("nhanes.csv").head()
# Out:
#       id  Gender  Age   Race     Education MaritalStatus RelationshipStatus  \
# 0  62163    male   14  Asian           NaN           NaN                NaN
# 1  62172  female   43  Black   High School  NeverMarried             Single
# 2  62174    male   80  White  College Grad       Married          Committed
# 3  62174    male   80  White  College Grad       Married          Committed
# 4  62175    male    5  White           NaN           NaN                NaN
#
#   Insured    Income  Poverty  ...  Diabetes DiabetesAge nPregnancies  nBabies  \
# 0     Yes  100000.0     4.07  ...        No         NaN          NaN      NaN
# 1     Yes   22500.0     2.02  ...        No         NaN          3.0      2.0
# 2     Yes   70000.0     4.30  ...        No         NaN          NaN      NaN
# 3     Yes   70000.0     4.30  ...        No         NaN          NaN      NaN
# 4     Yes   12500.0     0.39  ...        No         NaN          NaN      NaN
#
# ...

# %%
# google drive
from google.colab import drive
drive.mount("/content/drive")

# %%
# GitHUb link
# !git clone https://github.com/AngeMaxime/Transcriptomics-Project.git
# Out:
# Cloning into 'Transcriptomics-Project'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 29 (delta 5), reused 24 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 623.61 KiB | 18.34 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# Local drive
pd.read_csv("Dataset_cleaned.csv").head()
# Out:
#   specific_Protein_aa Protein Amino_Acid  sift_Score  foldX_Score Category
# 0         A5A607_K60Q  A5A607       K60Q    0.197799      0.51710  Neutral
# 1         A5A607_Y56C  A5A607       Y56C    0.174970      0.72870  Neutral
# 2         A5A607_Y56S  A5A607       Y56S    0.415581      0.84212  Neutral
# 3        P00350_A117S  P00350      A117S    0.401519     -0.09854  Neutral
# 4        P00350_A117T  P00350      A117T    0.282769      0.92352  Neutral

# %% [markdown]
# # Video3: Markdown|Rich Text Documentation |Image Upload google colab

# %% [markdown]
# This is heading
#
# we can creare first, second and third level heading

# %% [markdown]
# we cab incorporate code in our Notebook file
#
# ```python
# for item in list:
#   print(item)
# ```

# %% [markdown]
# ![Scatter_scores.png](data:image/png;base64,...)

# %% [markdown]
# [Google link](https://wwww.google.com)

# %% [markdown]
# first
#
# 1. Item
# 2. Item
#
# second
# third
#
# ghsdfjusg

# %% [markdown]
# ----
# Hello
# ----

# %% [markdown]
# $ a*x^2 +bx + c = 0 $

# %% [markdown]
# $ x1 = \frac{-b + \sqrt b^2- 4ac)}{2a} $

# %% [markdown]
#    # Video 4: How to save , (Google Drive - GitHub), Download & share Colab File
